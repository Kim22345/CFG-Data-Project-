# %%
# Load packages
import numpy as np
import matplotlib.pyplot as plt  # To visualize
import pandas as pd  # To read data
from functools import reduce # To merge all datasets
from sklearn.linear_model import LinearRegression as lr # Linear Regression

import requests
import csv
from pandas import json_normalize
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# Load in data
Six =pd.read_csv('2016_data.csv')
Seven = pd.read_csv('2017_data.csv')
Eight = pd.read_csv('2018_data.csv')
Nine = pd.read_csv('2019_data.csv')
Twenty = pd.read_csv('2020_data.csv')
Twenty1 = pd.read_csv('2021_data.csv')

# %%
# 2016 data
# Simplify datasets to common variables
six = Six[['laua_name',
              'SFBB availability (% premises)',
              'UFBB availability (% premises)',                      
        ]]
six


# Rename variables
clean_six = six.rename({'laua_name': 'Area',
                        'SFBB availability (% premises)': '2016 SFBB availability (% premises)',
                        'UFBB availability (% premises)': '2016 UFBB availability (% premises)'}, axis='columns')

# Capitalize area string
clean_six['Area']=clean_six['Area'].str.upper()


# View
clean_six
# Out:
#                    Area  2016 SFBB availability (% premises)  \
# 0                THANET                                   96
# 1                  ADUR                                   99
# 2                  ARUN                                   94
# 3              ASHFIELD                                   97
# 4              COVENTRY                                   91
# ..                  ...                                  ...
# 386       NORTH NORFOLK                                   75
# 387      NORTH SOMERSET                                   83
# 388      NORTH TYNESIDE                                   88
# 389      NORTHUMBERLAND                                   86
# 390  NORTH WARWICKSHIRE                                   84
#
#      2016 UFBB availability (% premises)
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ..                                   ...
# 386                                    0
# 387                                    0
# 388                                    0
# 389                                    1
# 390                                    0
#
# [391 rows x 3 columns]

# %%
# 2017 data
# Simplify datasets to common variables
Seven
seven = Seven[['laua_name',
              'SFBB availability (% premises)',
              'UFBB availability (% premises)',                        
        ]]
seven

# Rename variables
clean_seven = seven.rename({'laua_name': 'Area',
                        'SFBB availability (% premises)': '2017 SFBB availability (% premises)',
                        'UFBB availability (% premises)': '2017 UFBB availability (% premises)'}, axis='columns')

# Capitalize area string
clean_seven['Area']=clean_seven['Area'].str.upper()

# View
clean_seven
# Out:
#               Area  2017 SFBB availability (% premises)  \
# 0    ABERDEEN CITY                                   90
# 1    ABERDEENSHIRE                                   72
# 2             ADUR                                   29
# 3        ALLERDALE                                   86
# 4     AMBER VALLEY                                   87
# ..             ...                                  ...
# 386       WYCHAVON                                   85
# 387        WYCOMBE                                   73
# 388           WYRE                                   87
# 389    WYRE FOREST                                   47
# 390           YORK                                   42
#
#      2017 UFBB availability (% premises)
# 0                                      0
# 1                                      0
# 2                                     70
# 3                                      1
# 4                                      1
# ..                                   ...
# 386                                    1
# 387                                   18
# 388                                    5
# 389                                   46
# 390                                   50
#
# [391 rows x 3 columns]

# %%
# 2018 data
# Simplify datasets to common variables
Eight
eight = Eight[['laua_name',
              'SFBB availability (% premises)',
              'UFBB availability (% premises)',                      
        ]]
eight

# Rename variables
clean_eight = eight.rename({'laua_name': 'Area',
                        'SFBB availability (% premises)': '2018 SFBB availability (% premises)',
                        'UFBB availability (% premises)': '2018 UFBB availability (% premises)'}, axis='columns')

# Capitalize area string
clean_eight['Area']=clean_eight['Area'].str.upper()

# View
clean_eight
# Out:
#               Area  2018 SFBB availability (% premises)  \
# 0    ABERDEEN CITY                                 88.2
# 1    ABERDEENSHIRE                                 77.1
# 2             ADUR                                 32.5
# 3        ALLERDALE                                 90.1
# 4     AMBER VALLEY                                 70.2
# ..             ...                                  ...
# 386       WYCHAVON                                 85.7
# 387        WYCOMBE                                 70.0
# 388           WYRE                                 89.1
# 389    WYRE FOREST                                 44.1
# 390           YORK                                 22.2
#
#      2018 UFBB availability (% premises)
# 0                                    4.8
# 1                                    1.2
# 2                                   66.6
# 3                                    1.0
# 4                                   22.0
# ..                                   ...
# 386                                  4.4
# 387                                 23.8
# 388                                  5.2
# 389                                 51.0
# 390                                 72.7
#
# [391 rows x 3 columns]

# %%
# 2019 data
# Simplify datasets to common variables
Nine
nine = Nine[['laua_name',
              'SFBB availability (% premises)',
              'UFBB availability (% premises)',            
        ]]
nine

# Rename variables
clean_nine = nine.rename({'laua_name': 'Area',
                        'SFBB availability (% premises)': '2019 SFBB availability (% premises)',
                        'UFBB availability (% premises)': '2019 UFBB availability (% premises)'}, axis='columns')

# Capitalize area string
clean_nine['Area']=clean_nine['Area'].str.upper()

# View
clean_nine
# Out:
#               Area  2019 SFBB availability (% premises)  \
# 0    ABERDEEN CITY                                 73.3
# 1    ABERDEENSHIRE                                 78.5
# 2             ADUR                                 16.3
# 3        ALLERDALE                                 89.8
# 4     AMBER VALLEY                                 67.4
# ..             ...                                  ...
# 377       WYCHAVON                                 82.9
# 378        WYCOMBE                                 68.5
# 379           WYRE                                 88.4
# 380    WYRE FOREST                                 49.3
# 381           YORK                                 23.0
#
#      2019 UFBB availability (% premises)
# 0                                   20.1
# 1                                    2.8
# 2                                   82.4
# 3                                    1.7
# 4                                   25.3
# ..                                   ...
# 377                                  8.6
# 378                                 26.5
# 379                                  5.9
# 380                                 46.7
# 381                                 70.8
#
# [382 rows x 3 columns]

# %%
# 2020 data
# Simplify datasets to common variables
Twenty
twenty = Twenty[['laua_name',
              'SFBB availability (% premises)',
              'UFBB availability (% premises)',            
        ]]
twenty

# Rename variables
clean_twenty = twenty.rename({'laua_name': 'Area',
                        'SFBB availability (% premises)': '2020 SFBB availability (% premises)',
                        'UFBB availability (% premises)': '2020 UFBB availability (% premises)'}, axis='columns')

# Capitalize area string
clean_twenty['Area']=clean_twenty['Area'].str.upper()

# View
clean_twenty
# Out:
#               Area  2020 SFBB availability (% premises)  \
# 0    ABERDEEN CITY                                 93.9
# 1    ABERDEENSHIRE                                 82.0
# 2             ADUR                                 99.1
# 3        ALLERDALE                                 92.1
# 4     AMBER VALLEY                                 93.3
# ..             ...                                  ...
# 377       WYCHAVON                                 92.3
# 378        WYCOMBE                                 95.7
# 379           WYRE                                 94.8
# 380    WYRE FOREST                                 96.7
# 381           YORK                                 93.8
#
#      2020 UFBB availability (% premises)
# 0                                   30.0
# 1                                    3.2
# 2                                   81.7
# 3                                    2.3
# 4                                   25.5
# ..                                   ...
# 377                                  9.8
# 378                                 29.8
# 379                                  6.0
# 380                                 45.9
# 381                                 71.8
#
# [382 rows x 3 columns]

# %%
# 2021 data
# Simplify datasets to common variables
Twenty1
twenty1 = Twenty1[['laua_name',
              'SFBB availability (% premises)',
              'UFBB availability (% premises)',            
        ]]
twenty1

# Rename variables
clean_21 = twenty1.rename({'laua_name': 'Area',
                        'SFBB availability (% premises)': '2021 SFBB availability (% premises)',
                        'UFBB availability (% premises)': '2021 UFBB availability (% premises)'}, axis='columns')

# Capitalize area string
clean_21['Area']=clean_21['Area'].str.upper()

# View
clean_21
# Out:
#               Area  2021 SFBB availability (% premises)  \
# 0    ABERDEEN CITY                                 94.3
# 1    ABERDEENSHIRE                                 82.8
# 2             ADUR                                 98.8
# 3        ALLERDALE                                 92.5
# 4     AMBER VALLEY                                 95.3
# ..             ...                                  ...
# 374        WREXHAM                                 94.1
# 375       WYCHAVON                                 93.8
# 376           WYRE                                 94.7
# 377    WYRE FOREST                                 96.6
# 378           YORK                                 94.1
#
#      2021 UFBB availability (% premises)
# 0                                   50.8
# 1                                    8.5
# 2                                   85.4
# 3                                    3.1
# 4                                   27.3
# ..                                   ...
# 374                                 39.1
# 375                                 16.3
# 376                                 29.0
# 377                                 47.7
# 378                                 73.4
#
# [379 rows x 3 columns]

# %%
# Merge all datasets together

dfs = [clean_six, clean_seven, clean_eight, clean_nine, clean_twenty, clean_21] # Define which datasets

internet = reduce(lambda left, right: pd.merge (left,right,on = ['Area'], how = 'outer'), dfs) # Merge
internet # View
# Out:
#                           Area  2016 SFBB availability (% premises)  \
# 0                       THANET                                 96.0
# 1                         ADUR                                 99.0
# 2                         ARUN                                 94.0
# 3                     ASHFIELD                                 97.0
# 4                     COVENTRY                                 91.0
# ..                         ...                                  ...
# 397                     DORSET                                  NaN
# 398               EAST SUFFOLK                                  NaN
# 399  SOMERSET WEST AND TAUNTON                                  NaN
# 400               WEST SUFFOLK                                  NaN
# 401            BUCKINGHAMSHIRE                                  NaN
#
#      2016 UFBB availability (% premises)  2017 SFBB availability (% premises)  \
# 0                                    0.0                                 96.0
# 1                                    0.0                                 29.0
# 2                                    0.0                                 93.0
# 3                                    0.0                                 98.0
# 4                                    0.0                                 34.0
# ..                                   ...                                  ...
# 397                                  NaN                                  NaN
# 398                                  NaN                                  NaN
# 399                                  NaN                                  NaN
# 400                                  NaN                                  NaN
# 401                                  NaN                                  NaN
#
#      2017 UFBB availability (% premises)  2018 SFBB availability (% premises)  \
# 0                                    0.0                                 77.6
# 1                                   70.0                                 32.5
# 2                                    1.0                                 93.7
# 3                                    0.0                                  9.5
# 4                                   57.0                                 17.8
# ..                                   ...                                  ...
# 397                                  NaN                                  NaN
# 398                                  NaN                                  NaN
# 399                                  NaN                                  NaN
# 400                                  NaN                                  NaN
# 401                                  NaN                                  NaN
#
#      2018 UFBB availability (% premises)  2019 SFBB availability (% premises)  \
# 0                                   19.3                                 53.8
# 1                                   66.6                                 16.3
# 2                                    2.0                                 91.5
# 3                                   89.3                                 14.6
# 4                                   77.7                                 17.9
# ..                                   ...                                  ...
# 397                                  NaN                                 85.2
# 398                                  NaN                                 81.2
# 399                                  NaN                                 77.2
# 400                                  NaN                                 77.6
# 401                                  NaN                                  NaN
#
#      2019 UFBB availability (% premises)  2020 SFBB availability (% premises)  \
# 0                                   43.3                                 96.9
# 1                                   82.4                                 99.1
# 2                                    5.1                                 96.8
# 3                                   83.7                                 98.5
# 4                                   77.7                                 95.9
# ..                                   ...                                  ...
# 397                                  5.7                                 91.9
# 398                                 11.1                                 92.8
# 399                                 10.9                                 88.8
# 400                                 16.6                                 94.7
# 401                                  NaN                                  NaN
#
#      2020 UFBB availability (% premises)  2021 SFBB availability (% premises)  \
# 0                                   43.0                                 96.5
# 1                                   81.7                                 98.8
# 2                                    6.0                                 96.5
# 3                                   85.3                                 98.2
# 4                                   80.4                                 97.8
# ..                                   ...                                  ...
# 397                                  6.5                                 92.8
# 398                                 11.7                                 94.0
# 399                                 12.0                                 88.0
# 400                                 20.1                                 95.1
# 401                                  NaN                                 93.8
#
#      2021 UFBB availability (% premises)
# 0                                   52.7
# 1                                   85.4
# 2                                    8.7
# 3                                   86.2
# 4                                   91.2
# ..                                   ...
# 397                                 12.2
# 398                                 20.6
# 399                                 14.2
# 400                                 24.4
# 401                                 42.0
#
# [402 rows x 13 columns]

# %%
# Deal with NA values
# internet.isnull() # check for them
# Drop them
internetdf = internet.dropna()
# check which columns have missing data

#train.isnull().sum()
# check if we have missing values in our data

#nans = train.shape[0] - train.dropna().shape[0]
#print ("%d rows have missing values in the train data" %nans)

#nand = test.shape[0] - test.dropna().shape[0]
#print ("%d rows have missing values in the test data" %nand)

# %% [markdown]
# # Get Income Data

# %%
# Income data
#Region - Yorkshire
geo_y_1 ="geography=1811939394,1811939398,1811939399,1811939387,1811939395,1811939382,1811939388,1811939389,1811939383,1811939400,1811939401,1811939384,1811939385,1811939390,1811939396,1811939391...1811939393,1811939397,1811939402&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
#Just York 
geo_y_2 = "geography=1811939386&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
      
#Region - East
geo_east1 = "geography=1811939517,1811939484,1811939473,1811939485,1811939510,1811939486,1811939511,1811939496,1811939479,1811939487,1811939474,1811939488,1811939489,1811939497,1811939480,1811939499,1811939524,1811939490,1811939481,1811939512&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
geo_east2 ="geography=1811939491,1811939500,1811939482,1811939519,1811939513,1811939475,1811939492,1811939520,1811939501,1811939514,1811939515,1811939476,1811939493,1811939483,1811939516,1811939477,1811939503,1811939505,1811939494,1811939506&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
geo_east3 = "geography=1811939478,1811939495,1811939507,1811939509,1811939525&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - East Midlands
geo_em_1 = "geography=1811939407,1811939436,1811939437,1811939415,1811939408,1811939422,1811939438,1811939416,1811939409,1811939403,1811939410,1811939423,1811939411,1811939439,1811939417,1811939412,1811939418&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
geo_em_2 ="geography=1811939404,1811939424,1811939440,1811939419,1811939441,1811939413,1811939425,1811939768,1811939420,1811939405,1811939421,1811939442,1811939406,1811939414,1811939426...1811939428,1811939769&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - West Midlands
geo_wm_1 = "geography=1811939460,1811939467,1811939447,1811939461,1811939462,1811939448,1811939443,1811939449,1811939468,1811939450,1811939455,1811939456,1811939469,1811939457,1811939463,1811939444,1811939464,1811939451...1811939453&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
geo_wm_2 ="geography=1811939445,1811939458,1811939454,1811939446,1811939465,1811939459,1811939466,1811939470...1811939472&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - North East
geo_ne = "geography=1811939330,1811939329,1811939338,1811939331,1811939332,1811939339,1811939340,1811939334,1811939335,1811939341,1811939336,1811939342&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - North West
# A-M-  240 ROWS
geo_nw_1 = "geography=1811939349,1811939350,1811939343,1811939344,1811939355,1811939365,1811939356,1811939351,1811939345,1811939346,1811939366,1811939352,1811939353,1811939367,1811939347,1811939368,1811939377,1811939369,1811939378,1811939357&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
# S-W-  228 ROWS
geo_nw_2 = "geography=1811939358,1811939370...1811939372,1811939359,1811939373,1811939360,1811939379,1811939354,1811939374,1811939380,1811939361...1811939363,1811939348,1811939375,1811939364,1811939381,1811939376&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - South East
# A-F - 240 ROWS
geo_se_1 = "geography=1811939621,1811939622,1811939592,1811939581,1811939559,1811939560,1811939575,1811939593,1811939605,1811939623,1811939624,1811939594,1811939595,1811939582,1811939576,1811939583,1811939610,1811939611,1811939584,1811939599&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
# G-R (ROTHER) - 240 ROWS
geo_se_2 = "geography=1811939585,1811939596,1811939612,1811939586,1811939577,1811939587,1811939625,1811939561,1811939578,1811939597,1811939562,1811939626,1811939563,1811939613,1811939588,1811939606,1811939564,1811939565,1811939614,1811939579&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
#  R-W (RUNNYMEADE-WESTOXFORDSHIRE) - 228 ROWS
geo_se_3 = "geography=1811939615,1811939589,1811939598,1811939566,1811939607,1811939567,1811939616,1811939617,1811939601,1811939618,1811939590,1811939602...1811939604,1811939608,1811939619,1811939580,1811939568,1811939609&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
# WINCHESTER-WORTHING  - 60 ROWS
geo_se_4 = "geography=1811939591,1811939569,1811939620,1811939570,1811939627&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - South West
#B-S (SOMERSET)-  228 ROWS
geo_sw_1 = "geography=1811939628,1811939649,1811939630,1811939656,1811939631,1811939657,1811939655,1811939640,1811939641,1811939658,1811939659,1811939632,1811939662,1811939642,1811939643,1811939633,1811939634,1811939663,1811939667&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
#S-W ()-  132 ROWS
geo_sw_2 ="geography=1811939636,1811939644,1811939664,1811939660,1811939637,1811939645,1811939661,1811939638,1811939646,1811939647,1811939639&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - London
# B-H -216 ROWS
geo_ldn_1 = "geography=1811939540...1811939544,1811939526,1811939527,1811939545...1811939548,1811939528...1811939530,1811939549...1811939552&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
# I-W 180 ROWS
geo_ldn_2 = "geography=1811939531,1811939532,1811939553,1811939533,1811939534,1811939554,1811939535,1811939555,1811939556,1811939536,1811939557,1811939537,1811939558,1811939538,1811939539&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - Wales
# B-N 180 ROWS
geo_w_1 = "geography=1811939689,1811939680,1811939688,1811939683,1811939677,1811939675,1811939670...1811939672,1811939669,1811939668,1811939687,1811939691,1811939679,1811939692&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
# P-W 84 ROWS
geo_w_2 = "geography=1811939676,1811939674,1811939685,1811939678,1811939690,1811939682,1811939673&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

#Region - Scotland
# A-H -192 ROWS
geo_scot_1 = "geography=1811939693...1811939696,1811939704,1811939697...1811939703,1811939708,1811939710,1811939712,1811939713&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"
# I-W 192 ROWS
geo_scot_2 = "geography=1811939714...1811939716,1811939707,1811939717,1811939719,1811939720,1811939722...1811939730&date=latestMINUS5-latest&sex=8&item=2&pay=7&measures=20100,20701&select=date_name,geography_name,geography_code,sex_name,pay_name,item_name,measures_name,obs_value,obs_status_name"

# %%
############### CALLING APIS ##############

####### YORKSHIRE #######
url_yorkshire = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_y_1}"
response_y_1 = requests.get(url_yorkshire)
data_yorkshire = response_y_1.json()
# data_yorkshire_1

url_york = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_y_2}"
response_y_2 = requests.get(url_york)
data_york = response_y_2.json()
# data_york

####### EAST Region #######
url_east1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_east1}"
response_e1 = requests.get(url_east1)
data_east1 = response_e1.json()
# data_east

url_east2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_east2}"
response_e2 = requests.get(url_east2)
data_east2 = response_e2.json()
# data_east2

url_east3 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_east3}"
response_e3 = requests.get(url_east3)
data_east3 = response_e3.json()
# data_east3

####### EAST MIDLANDS #######
url_east_mid_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_em_1}"
response_em_1 = requests.get(url_east_mid_1)
data_eastmid_1 = response_em_1.json()
# data_east_mid_1
url_east_mid_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_em_2}"
response_em_2 = requests.get(url_east_mid_2)
data_eastmid_2 = response_em_2.json()
# data_east_mid_2

####### WEST MIDLANDS #######
url_west_mid_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_wm_1}"
response_wm_1 = requests.get(url_west_mid_1)
data_westmid_1 = response_wm_1.json()
# data_west_mid_1
url_west_mid_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_wm_2}"
response_wm_2 = requests.get(url_west_mid_2)
data_westmid_2 = response_wm_2.json()
# data_west_mid_2

####### NORTH EAST #######
url_ne = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_ne}"
response_ne = requests.get(url_ne)
data_ne = response_ne.json()
# data_ne

####### NORTH WEST #######
url_nw_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_nw_1}"
response_nw_1 = requests.get(url_nw_1)
data_nw_1 = response_nw_1.json()
# data_nw_1

url_nw_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_nw_2}"
response_nw_2 = requests.get(url_nw_2)
data_nw_2 = response_nw_2.json()
# data_nw_2

####### SOUTHWEST #######
url_sw_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_sw_1}"
response_sw_1 = requests.get(url_sw_1)
data_sw_1 = response_sw_1.json()
# data_sw_1

url_sw_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_sw_2}"
response_sw_2 = requests.get(url_sw_2)
data_sw_2 = response_sw_2.json()
# data_sw_2

####### SOUTHEAST #######
url_se_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_se_1}"
response_se_1 = requests.get(url_se_1)
data_se_1 = response_se_1.json()
# data_se_1

url_se_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_se_2}"
response_se_2 = requests.get(url_se_2)
data_se_2 = response_se_2.json()
# data_se_2

url_se_3 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_se_3}"
response_se_3 = requests.get(url_se_3)
data_se_3 = response_se_3.json()
# data_se_3

url_se_4 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_se_4}"
response_se_4 = requests.get(url_se_4)
data_se_4 = response_se_4.json()
# data_se_4

####### LONDON #######
url_ldn_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_ldn_1}"
response_ldn_1 = requests.get(url_ldn_1)
data_ldn_1 = response_ldn_1.json()
# data_ldn_1

url_ldn_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_ldn_2}"
response_ldn_2 = requests.get(url_ldn_2)
data_ldn_2 = response_ldn_2.json()
# data_ldn_2

####### WALES #######
url_wales_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_w_1}"
response_wales_1 = requests.get(url_wales_1)
data_wales_1 = response_wales_1.json()
# data_wales_1

url_wales_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_w_2}"
response_wales_2 = requests.get(url_wales_2)
data_wales_2 = response_wales_2.json()
# data_wales_2

####### SCOTLAND #######
url_scot_1 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_scot_1}"
response_scot_1 = requests.get(url_scot_1)
data_scot_1 = response_scot_1.json()
# data_scot_1

url_scot_2 = f"https://www.nomisweb.co.uk/api/v01/dataset/NM_30_1.data.json?{geo_scot_2}"
response_scot_2 = requests.get(url_scot_2)
data_scot_2 = response_scot_2.json()
# data_scot_2

# %%
# NORMALISING JSON DATA, REMOVING HEADER INFORMATION (IRRELEVANT INFORMATION)
# Yorkshire # 
yorkshire_df = (json_normalize(data_yorkshire, 'obs'))
york_df = (json_normalize(data_york, 'obs'))
# EAST #
east1_df = (json_normalize(data_east1, 'obs'))
east2_df = (json_normalize(data_east2, 'obs'))
east3_df = (json_normalize(data_east3, 'obs'))

# EAST MIDLANDS # 
eastmid1_df = (json_normalize(data_eastmid_1, 'obs'))
eastmid2_df = (json_normalize(data_eastmid_2, 'obs'))

# WEST MIDLANDS #
westmid1_df = (json_normalize(data_westmid_1, 'obs'))
westmid2_df = (json_normalize(data_westmid_2, 'obs'))

# NORTHEAST #
northeast_df = (json_normalize(data_ne, 'obs'))

# NORTHWEST #
northwest_1_df = (json_normalize(data_nw_1, 'obs'))
northwest_2_df = (json_normalize(data_nw_2, 'obs'))

# SOUTHWEST #
southwest_1_df = (json_normalize(data_sw_1, 'obs'))
southwest_2_df = (json_normalize(data_sw_2, 'obs'))

# SOUTHEAST # 
south_east_1_df = (json_normalize(data_se_1, 'obs'))
south_east_2_df = (json_normalize(data_se_2, 'obs'))
south_east_3_df = (json_normalize(data_se_3, 'obs'))
south_east_4_df = (json_normalize(data_se_4, 'obs'))

# LONDON # 
ldn_1_df = (json_normalize(data_ldn_1, 'obs'))
ldn_2_df = (json_normalize(data_ldn_2, 'obs'))

# WALES #
wales_1_df = (json_normalize(data_wales_1, 'obs'))
wales_2_df = (json_normalize(data_wales_2, 'obs'))

# SCOTLAND # 
scot_1_df = (json_normalize(data_scot_1, 'obs'))
scot_2_df = (json_normalize(data_scot_2, 'obs'))

# %%
pd.concat([yorkshire_df, york_df, 
           east1_df, east2_df, 
           east3_df, eastmid1_df, 
           eastmid2_df, westmid1_df, 
           westmid2_df, northeast_df, 
           northwest_1_df, northwest_2_df, 
           southwest_1_df, southwest_2_df,
           south_east_1_df, south_east_2_df, 
           south_east_3_df, south_east_4_df, 
           ldn_1_df, ldn_2_df, wales_1_df, wales_2_df,
           scot_1_df, scot_2_df ]).to_csv('Uncleaned Data.csv',
                                     index = False, header = True) 

uncleaned_data = pd.read_csv('Uncleaned Data.csv')
uncleaned_data
# Out:
#      freq                                     urn dataset.value  \
# 0       A  Nm-30d1d32256e1d1811939394d8d7d2d20100       NM_30_1
# 1       A  Nm-30d1d32272e1d1811939394d8d7d2d20100       NM_30_1
# 2       A  Nm-30d1d32288e1d1811939394d8d7d2d20100       NM_30_1
# 3       A  Nm-30d1d32304e1d1811939394d8d7d2d20100       NM_30_1
# 4       A  Nm-30d1d32320e0d1811939394d8d7d2d20100       NM_30_1
# ...   ...                                     ...           ...
# 4351    A  Nm-30d1d32272e1d1811939730d8d7d2d20701       NM_30_1
# 4352    A  Nm-30d1d32288e1d1811939730d8d7d2d20701       NM_30_1
# 4353    A  Nm-30d1d32304e1d1811939730d8d7d2d20701       NM_30_1
# 4354    A  Nm-30d1d32320e0d1811939730d8d7d2d20701       NM_30_1
# 4355    A  Nm-30d1d32336e0d1811939730d8d7d2d20701       NM_30_1
#
#                                     dataset.description  geography.value  \
# 0     annual survey of hours and earnings  - residen...       1811939394
# 1     annual survey of hours and earnings  - residen...       1811939394
# 2     annual survey of hours and earnings  - residen...       1811939394
# 3     annual survey of hours and earnings  - residen...       1811939394
# 4     annual survey of hours and earnings  - residen...       1811939394
# ...                                                 ...              ...
# 4351  annual survey of hours and earnings  - residen...       1811939730
# 4352  annual survey of hours and earnings  - residen...       1811939730
# 4353  annual survey of hours and earnings  - residen...       1811939730
# 4354  annual survey of hours and earnings  - residen...       1811939730
# 4355  annual survey of hours and earnings  - residen...       1811939730
#
#      geography.description geography.geogcode  sex.value    sex.description  \
# 0                 Barnsley          E08000016          8  Full Time Workers
# 1                 Barnsley          E08000016          8  Full Time Workers
# 2                 Barnsley          E08000016          8  Full Time Workers
# 3                 Barnsley          E08000016          8  Full Time Workers
# 4                 Barnsley          E08000016          8  Full Time Workers
# ...                    ...                ...        ...                ...
# 4351          West Lothian          S12000040          8  Full Time Workers
# 4352          West Lothian          S12000040          8  Full Time Workers
# 4353          West Lothian          S12000040          8  Full Time Workers
# 4354          West Lothian          S12000040          8  Full Time Workers
# 4355          West Lothian          S12000040          8  Full Time Workers
#
#       item.value  ... unit.value  unit.description time.value  \
# 0              2  ...          X         Undefined       2016
# 1              2  ...          X         Undefined       2017
# 2              2  ...          X         Undefined       2018
# 3              2  ...          X         Undefined       2019
# 4              2  ...          X         Undefined       2020
# ...          ...  ...        ...               ...        ...
# 4351           2  ...          X         Undefined       2017
# 4352           2  ...          X         Undefined       2018
# 4353           2  ...          X         Undefined       2019
# 4354           2  ...          X         Undefined       2020
# 4355           2  ...          X         Undefined       2021
#
#       time.description obs_value.value  \
# 0                 2016         24313.0
# 1                 2017         25107.0
# 2                 2018         25370.0
# 3                 2019         26466.0
# 4                 2020         27181.0
# ...                ...             ...
# 4351              2017             4.5
# 4352              2018            11.0
# 4353              2019             5.6
# 4354              2020             6.6
# 4355              2021             4.9
#
#                                   obs_value.description obs_status.value  \
# 0     Undefined Value for Barnsley (geography), Full...                A
# 1     Undefined Value for Barnsley (geography), Full...                A
# 2     Undefined Value for Barnsley (geography), Full...                A
# 3     Undefined Value for Barnsley (geography), Full...                A
# 4     Undefined Value for Barnsley (geography), Full...                A
# ...                                                 ...              ...
# 4351  Undefined Confidence for West Lothian (geograp...                A
# 4352  Undefined Confidence for West Lothian (geograp...                A
# 4353  Undefined Confidence for West Lothian (geograp...                A
# 4354  Undefined Confidence for West Lothian (geograp...                A
# 4355  Undefined Confidence for West Lothian (geograp...                A
#
#      obs_status.description obs_conf.value  obs_conf.description
# 0              Normal Value              F                   NaN
# 1              Normal Value              F                   NaN
# 2              Normal Value              F                   NaN
# 3              Normal Value              F                   NaN
# 4              Normal Value              F                   NaN
# ...                     ...            ...                   ...
# 4351           Normal Value              F                   NaN
# 4352           Normal Value              F                   NaN
# 4353           Normal Value              F                   NaN
# 4354           Normal Value              F                   NaN
# 4355           Normal Value              F                   NaN
#
# [4356 rows x 27 columns]

# %%
#Yorkshire Set of Areas, dropping unrelated columns, renaming columns and setting area as axis
data = uncleaned_data[['geography.description',
                 'measures.description',
                 'time.value', 
                 'obs_value.value',
                 'obs_status.description']]
data
data = data.rename({'geography.description':'Area',
                 'measures.description': 'Accuracy',
                 'time.value': 'Date', 
                 'obs_value.value':'Observed Annual Income',
                 'obs_status.description': 'Information'},  axis='columns')

# Capitalise area string
data['Area']=data['Area'].str.upper()
data.set_index('Area')
data
# Out:
#               Area    Accuracy  Date  Observed Annual Income   Information
# 0         BARNSLEY       Value  2016                 24313.0  Normal Value
# 1         BARNSLEY       Value  2017                 25107.0  Normal Value
# 2         BARNSLEY       Value  2018                 25370.0  Normal Value
# 3         BARNSLEY       Value  2019                 26466.0  Normal Value
# 4         BARNSLEY       Value  2020                 27181.0  Normal Value
# ...            ...         ...   ...                     ...           ...
# 4351  WEST LOTHIAN  Confidence  2017                     4.5  Normal Value
# 4352  WEST LOTHIAN  Confidence  2018                    11.0  Normal Value
# 4353  WEST LOTHIAN  Confidence  2019                     5.6  Normal Value
# 4354  WEST LOTHIAN  Confidence  2020                     6.6  Normal Value
# 4355  WEST LOTHIAN  Confidence  2021                     4.9  Normal Value
#
# [4356 rows x 5 columns]

# %%
data = data[data.Information == "Normal Value"]
data.to_csv('Semi-Cleaned Data.csv')

# DONT FORGET TO REMOVE ALL CONFIDENCE VARIABLES
confidence_vals = data[data.Accuracy == "Confidence"]
data = data[data['Accuracy'] != 'Confidence']
data
# Out:
#               Area Accuracy  Date  Observed Annual Income   Information
# 0         BARNSLEY    Value  2016                 24313.0  Normal Value
# 1         BARNSLEY    Value  2017                 25107.0  Normal Value
# 2         BARNSLEY    Value  2018                 25370.0  Normal Value
# 3         BARNSLEY    Value  2019                 26466.0  Normal Value
# 4         BARNSLEY    Value  2020                 27181.0  Normal Value
# ...            ...      ...   ...                     ...           ...
# 4345  WEST LOTHIAN    Value  2017                 28034.0  Normal Value
# 4346  WEST LOTHIAN    Value  2018                 28723.0  Normal Value
# 4347  WEST LOTHIAN    Value  2019                 29245.0  Normal Value
# 4348  WEST LOTHIAN    Value  2020                 31044.0  Normal Value
# 4349  WEST LOTHIAN    Value  2021                 30623.0  Normal Value
#
# [2094 rows x 5 columns]

# %%
data.reset_index(drop=True)

data = data.sort_values(["Area", "Date"], ascending = (True, True))
data
# Out:
#                Area Accuracy  Date  Observed Annual Income   Information
# 3972  ABERDEEN CITY    Value  2016                 29350.0  Normal Value
# 3973  ABERDEEN CITY    Value  2017                 28500.0  Normal Value
# 3974  ABERDEEN CITY    Value  2018                 29829.0  Normal Value
# 3975  ABERDEEN CITY    Value  2019                 30426.0  Normal Value
# 3976  ABERDEEN CITY    Value  2020                 30615.0  Normal Value
# ...             ...      ...   ...                     ...           ...
# 241            YORK    Value  2017                 25956.0  Normal Value
# 242            YORK    Value  2018                 26688.0  Normal Value
# 243            YORK    Value  2019                 28555.0  Normal Value
# 244            YORK    Value  2020                 30054.0  Normal Value
# 245            YORK    Value  2021                 30878.0  Normal Value
#
# [2094 rows x 5 columns]

# %%
cleaned_data = data
cleaned_data.reset_index(drop=True)
cleaned_data.to_csv('Cleaned Income Data.csv', index=False)
income_data = pd.read_csv('Cleaned Income Data.csv')

income_data
# Out:
#                Area Accuracy  Date  Observed Annual Income   Information
# 0     ABERDEEN CITY    Value  2016                 29350.0  Normal Value
# 1     ABERDEEN CITY    Value  2017                 28500.0  Normal Value
# 2     ABERDEEN CITY    Value  2018                 29829.0  Normal Value
# 3     ABERDEEN CITY    Value  2019                 30426.0  Normal Value
# 4     ABERDEEN CITY    Value  2020                 30615.0  Normal Value
# ...             ...      ...   ...                     ...           ...
# 2089           YORK    Value  2017                 25956.0  Normal Value
# 2090           YORK    Value  2018                 26688.0  Normal Value
# 2091           YORK    Value  2019                 28555.0  Normal Value
# 2092           YORK    Value  2020                 30054.0  Normal Value
# 2093           YORK    Value  2021                 30878.0  Normal Value
#
# [2094 rows x 5 columns]

# %% [markdown]
# # Merging

# %%
# Prepare income data for wide merge
income_wide = income_data.pivot(index='Area', columns='Date', values='Observed Annual Income')

income = income_wide.rename_axis(None, axis=1).reset_index()

# %%
# Merging both datasets into a wide data format
merged_wide = pd.merge(internetdf,income, on = "Area")
merged_wide = merged_wide.reset_index(drop = True)


merged_wide
# Out:
#                    Area  2016 SFBB availability (% premises)  \
# 0                THANET                                 96.0
# 1                  ADUR                                 99.0
# 2                  ARUN                                 94.0
# 3              ASHFIELD                                 97.0
# 4              COVENTRY                                 91.0
# ..                  ...                                  ...
# 345       NORTH NORFOLK                                 75.0
# 346      NORTH SOMERSET                                 83.0
# 347      NORTH TYNESIDE                                 88.0
# 348      NORTHUMBERLAND                                 86.0
# 349  NORTH WARWICKSHIRE                                 84.0
#
#      2016 UFBB availability (% premises)  2017 SFBB availability (% premises)  \
# 0                                    0.0                                 96.0
# 1                                    0.0                                 29.0
# 2                                    0.0                                 93.0
# 3                                    0.0                                 98.0
# 4                                    0.0                                 34.0
# ..                                   ...                                  ...
# 345                                  0.0                                 79.0
# 346                                  0.0                                 86.0
# 347                                  0.0                                 38.0
# 348                                  1.0                                 87.0
# 349                                  0.0                                 74.0
#
#      2017 UFBB availability (% premises)  2018 SFBB availability (% premises)  \
# 0                                    0.0                                 77.6
# 1                                   70.0                                 32.5
# 2                                    1.0                                 93.7
# 3                                    0.0                                  9.5
# 4                                   57.0                                 17.8
# ..                                   ...                                  ...
# 345                                  0.0                                 82.6
# 346                                  1.0                                 63.1
# 347                                 57.0                                 36.4
# 348                                  2.0                                 88.9
# 349                                 14.0                                 70.5
#
#      2018 UFBB availability (% premises)  2019 SFBB availability (% premises)  \
# 0                                   19.3                                 53.8
# 1                                   66.6                                 16.3
# 2                                    2.0                                 91.5
# 3                                   89.3                                 14.6
# 4                                   77.7                                 17.9
# ..                                   ...                                  ...
# 345                                  0.8                                 85.4
# 346                                 27.4                                 60.1
# 347                                 61.7                                 36.9
# 348                                  2.3                                 85.5
# 349                                 21.1                                 72.2
#
#      2019 UFBB availability (% premises)  2020 SFBB availability (% premises)  \
# 0                                   43.3                                 96.9
# 1                                   82.4                                 99.1
# 2                                    5.1                                 96.8
# 3                                   83.7                                 98.5
# 4                                   77.7                                 95.9
# ..                                   ...                                  ...
# 345                                  2.4                                 89.6
# 346                                 30.0                                 90.5
# 347                                 61.0                                 98.2
# 348                                  6.6                                 92.9
# 349                                 22.3                                 95.2
#
#      2020 UFBB availability (% premises)  2021 SFBB availability (% premises)  \
# 0                                   43.0                                 96.5
# 1                                   81.7                                 98.8
# 2                                    6.0                                 96.5
# 3                                   85.3                                 98.2
# 4                                   80.4                                 97.8
# ..                                   ...                                  ...
# 345                                  3.2                                 90.4
# 346                                 32.0                                 92.0
# 347                                 62.5                                 98.5
# 348                                  7.6                                 92.8
# 349                                 23.4                                 96.0
#
#      2021 UFBB availability (% premises)     2016     2017     2018     2019  \
# 0                                   52.7  24113.0  24919.0  24303.0  26381.0
# 1                                   85.4  24645.0  24527.0  26771.0  27919.0
# 2                                    8.7  26109.0  26535.0  27914.0  25770.0
# 3                                   86.2  24258.0  24664.0  25348.0  26074.0
# 4                                   91.2  27969.0  28412.0  28746.0  28747.0
# ..                                   ...      ...      ...      ...      ...
# 345                                  4.4  23266.0  24479.0  24529.0  25724.0
# 346                                 48.8  30086.0  30944.0  30246.0  31067.0
# 347                                 70.0  26092.0  27855.0  28726.0  29525.0
# 348                                  9.2  26454.0  27113.0  27460.0  27430.0
# 349                                 30.9  29010.0  29884.0  29749.0  32968.0
#
#         2020     2021
# 0    26864.0  28176.0
# 1    30250.0      NaN
# 2    28876.0  28733.0
# 3    26446.0  27366.0
# 4    29589.0  30763.0
# ..       ...      ...
# 345  27213.0  28019.0
# 346  34638.0  30359.0
# 347  29523.0  29029.0
# 348  28472.0  28229.0
# 349  31388.0  31332.0
#
# [350 rows x 19 columns]

# %%
# Remove NAs
merged_wide = merged_wide.dropna()
merged_wide
# Out:
#                    Area  2016 SFBB availability (% premises)  \
# 0                THANET                                 96.0
# 2                  ARUN                                 94.0
# 3              ASHFIELD                                 97.0
# 4              COVENTRY                                 91.0
# 5               ASHFORD                                 83.0
# ..                  ...                                  ...
# 345       NORTH NORFOLK                                 75.0
# 346      NORTH SOMERSET                                 83.0
# 347      NORTH TYNESIDE                                 88.0
# 348      NORTHUMBERLAND                                 86.0
# 349  NORTH WARWICKSHIRE                                 84.0
#
#      2016 UFBB availability (% premises)  2017 SFBB availability (% premises)  \
# 0                                    0.0                                 96.0
# 2                                    0.0                                 93.0
# 3                                    0.0                                 98.0
# 4                                    0.0                                 34.0
# 5                                    0.0                                 48.0
# ..                                   ...                                  ...
# 345                                  0.0                                 79.0
# 346                                  0.0                                 86.0
# 347                                  0.0                                 38.0
# 348                                  1.0                                 87.0
# 349                                  0.0                                 74.0
#
#      2017 UFBB availability (% premises)  2018 SFBB availability (% premises)  \
# 0                                    0.0                                 77.6
# 2                                    1.0                                 93.7
# 3                                    0.0                                  9.5
# 4                                   57.0                                 17.8
# 5                                   37.0                                 43.4
# ..                                   ...                                  ...
# 345                                  0.0                                 82.6
# 346                                  1.0                                 63.1
# 347                                 57.0                                 36.4
# 348                                  2.0                                 88.9
# 349                                 14.0                                 70.5
#
#      2018 UFBB availability (% premises)  2019 SFBB availability (% premises)  \
# 0                                   19.3                                 53.8
# 2                                    2.0                                 91.5
# 3                                   89.3                                 14.6
# 4                                   77.7                                 17.9
# 5                                   45.2                                 46.2
# ..                                   ...                                  ...
# 345                                  0.8                                 85.4
# 346                                 27.4                                 60.1
# 347                                 61.7                                 36.9
# 348                                  2.3                                 85.5
# 349                                 21.1                                 72.2
#
#      2019 UFBB availability (% premises)  2020 SFBB availability (% premises)  \
# 0                                   43.3                                 96.9
# 2                                    5.1                                 96.8
# 3                                   83.7                                 98.5
# 4                                   77.7                                 95.9
# 5                                   43.3                                 90.1
# ..                                   ...                                  ...
# 345                                  2.4                                 89.6
# 346                                 30.0                                 90.5
# 347                                 61.0                                 98.2
# 348                                  6.6                                 92.9
# 349                                 22.3                                 95.2
#
#      2020 UFBB availability (% premises)  2021 SFBB availability (% premises)  \
# 0                                   43.0                                 96.5
# 2                                    6.0                                 96.5
# 3                                   85.3                                 98.2
# 4                                   80.4                                 97.8
# 5                                   44.0                                 89.7
# ..                                   ...                                  ...
# 345                                  3.2                                 90.4
# 346                                 32.0                                 92.0
# 347                                 62.5                                 98.5
# 348                                  7.6                                 92.8
# 349                                 23.4                                 96.0
#
#      2021 UFBB availability (% premises)     2016     2017     2018     2019  \
# 0                                   52.7  24113.0  24919.0  24303.0  26381.0
# 2                                    8.7  26109.0  26535.0  27914.0  25770.0
# 3                                   86.2  24258.0  24664.0  25348.0  26074.0
# 4                                   91.2  27969.0  28412.0  28746.0  28747.0
# 5                                   45.1  27751.0  29135.0  30198.0  31385.0
# ..                                   ...      ...      ...      ...      ...
# 345                                  4.4  23266.0  24479.0  24529.0  25724.0
# 346                                 48.8  30086.0  30944.0  30246.0  31067.0
# 347                                 70.0  26092.0  27855.0  28726.0  29525.0
# 348                                  9.2  26454.0  27113.0  27460.0  27430.0
# 349                                 30.9  29010.0  29884.0  29749.0  32968.0
#
#         2020     2021
# 0    26864.0  28176.0
# 2    28876.0  28733.0
# 3    26446.0  27366.0
# 4    29589.0  30763.0
# 5    30198.0  29417.0
# ..       ...      ...
# 345  27213.0  28019.0
# 346  34638.0  30359.0
# 347  29523.0  29029.0
# 348  28472.0  28229.0
# 349  31388.0  31332.0
#
# [302 rows x 19 columns]

# %%
# Prepare internet data for long merge
data_long = merged_wide.rename({'2016 SFBB availability (% premises)': 'SFBB2016',
                           '2017 SFBB availability (% premises)': 'SFBB2017',
                           '2018 SFBB availability (% premises)': 'SFBB2018',
                           '2019 SFBB availability (% premises)': 'SFBB2019',
                           '2020 SFBB availability (% premises)': 'SFBB2020',
                           '2021 SFBB availability (% premises)': 'SFBB2021',
                           '2016 UFBB availability (% premises)': 'UFBB2016',
                           '2017 UFBB availability (% premises)': 'UFBB2017',
                           '2018 UFBB availability (% premises)': 'UFBB2018',
                           '2019 UFBB availability (% premises)': 'UFBB2019',
                           '2020 UFBB availability (% premises)': 'UFBB2020',
                           '2021 UFBB availability (% premises)': 'UFBB2021',
                            2016: 'Income2016',
                            2017: 'Income2017',
                            2018: 'Income2018',
                            2019: 'Income2019',
                            2020: 'Income2020',
                            2021: 'Income2021'}, axis='columns')




data_long
# Out:
#                    Area  SFBB2016  UFBB2016  SFBB2017  UFBB2017  SFBB2018  \
# 0                THANET      96.0       0.0      96.0       0.0      77.6
# 2                  ARUN      94.0       0.0      93.0       1.0      93.7
# 3              ASHFIELD      97.0       0.0      98.0       0.0       9.5
# 4              COVENTRY      91.0       0.0      34.0      57.0      17.8
# 5               ASHFORD      83.0       0.0      48.0      37.0      43.4
# ..                  ...       ...       ...       ...       ...       ...
# 345       NORTH NORFOLK      75.0       0.0      79.0       0.0      82.6
# 346      NORTH SOMERSET      83.0       0.0      86.0       1.0      63.1
# 347      NORTH TYNESIDE      88.0       0.0      38.0      57.0      36.4
# 348      NORTHUMBERLAND      86.0       1.0      87.0       2.0      88.9
# 349  NORTH WARWICKSHIRE      84.0       0.0      74.0      14.0      70.5
#
#      UFBB2018  SFBB2019  UFBB2019  SFBB2020  UFBB2020  SFBB2021  UFBB2021  \
# 0        19.3      53.8      43.3      96.9      43.0      96.5      52.7
# 2         2.0      91.5       5.1      96.8       6.0      96.5       8.7
# 3        89.3      14.6      83.7      98.5      85.3      98.2      86.2
# 4        77.7      17.9      77.7      95.9      80.4      97.8      91.2
# 5        45.2      46.2      43.3      90.1      44.0      89.7      45.1
# ..        ...       ...       ...       ...       ...       ...       ...
# 345       0.8      85.4       2.4      89.6       3.2      90.4       4.4
# 346      27.4      60.1      30.0      90.5      32.0      92.0      48.8
# 347      61.7      36.9      61.0      98.2      62.5      98.5      70.0
# 348       2.3      85.5       6.6      92.9       7.6      92.8       9.2
# 349      21.1      72.2      22.3      95.2      23.4      96.0      30.9
#
#      Income2016  Income2017  Income2018  Income2019  Income2020  Income2021
# 0       24113.0     24919.0     24303.0     26381.0     26864.0     28176.0
# 2       26109.0     26535.0     27914.0     25770.0     28876.0     28733.0
# 3       24258.0     24664.0     25348.0     26074.0     26446.0     27366.0
# 4       27969.0     28412.0     28746.0     28747.0     29589.0     30763.0
# 5       27751.0     29135.0     30198.0     31385.0     30198.0     29417.0
# ..          ...         ...         ...         ...         ...         ...
# 345     23266.0     24479.0     24529.0     25724.0     27213.0     28019.0
# 346     30086.0     30944.0     30246.0     31067.0     34638.0     30359.0
# 347     26092.0     27855.0     28726.0     29525.0     29523.0     29029.0
# 348     26454.0     27113.0     27460.0     27430.0     28472.0     28229.0
# 349     29010.0     29884.0     29749.0     32968.0     31388.0     31332.0
#
# [302 rows x 19 columns]

# %%
# Merge income_long and internet_long

merged_long = pd.wide_to_long(data_long, ["SFBB", "UFBB", "Income"], i = "Area", j = "Year")

merged_long
# Out:
#                          SFBB  UFBB   Income
# Area               Year
# THANET             2016  96.0   0.0  24113.0
# ARUN               2016  94.0   0.0  26109.0
# ASHFIELD           2016  97.0   0.0  24258.0
# COVENTRY           2016  91.0   0.0  27969.0
# ASHFORD            2016  83.0   0.0  27751.0
# ...                       ...   ...      ...
# NORTH NORFOLK      2021  90.4   4.4  28019.0
# NORTH SOMERSET     2021  92.0  48.8  30359.0
# NORTH TYNESIDE     2021  98.5  70.0  29029.0
# NORTHUMBERLAND     2021  92.8   9.2  28229.0
# NORTH WARWICKSHIRE 2021  96.0  30.9  31332.0
#
# [1812 rows x 3 columns]

# %% [markdown]
# # Visualization

# %%
# Histogram to assess distribution of data (wide data)
merged_wide.hist(bins=60, sharex=False, figsize=(20,30))
plt.show()

# %%
# Histogram to assess distribution of data (long data)
merged_long.hist(bins=60, sharex=False, figsize=(15,15))
plt.show()

# %%
merged_long = merged_long.sort_values(["Area", "Year"], ascending = (True, True))

merged_long
# Out:
#                     SFBB  UFBB   Income
# Area          Year
# ABERDEEN CITY 2016  89.0   0.0  29350.0
#               2017  90.0   0.0  28500.0
#               2018  88.2   4.8  29829.0
#               2019  73.3  20.1  30426.0
#               2020  93.9  30.0  30615.0
# ...                  ...   ...      ...
# YORK          2017  42.0  50.0  25956.0
#               2018  22.2  72.7  26688.0
#               2019  23.0  70.8  28555.0
#               2020  93.8  71.8  30054.0
#               2021  94.1  73.4  30878.0
#
# [1812 rows x 3 columns]

# %%
merged_long = merged_long.reset_index(level = ['Year'])

# %%
#SFBB plot
fig = merged_long[merged_long.Year==2016].plot(kind='scatter',x='Income',y='SFBB',color='orange', label='2016')
merged_long[merged_long.Year==2017].plot(kind='scatter',x='Income',y='SFBB',color='blue', label='2017', ax=fig)
merged_long[merged_long.Year==2018].plot(kind='scatter',x='Income',y='SFBB',color='pink', label='2018', ax=fig)
merged_long[merged_long.Year==2019].plot(kind='scatter',x='Income',y='SFBB',color='green', label='2019', ax=fig)
merged_long[merged_long.Year==2020].plot(kind='scatter',x='Income',y='SFBB',color='cyan', label='2020', ax=fig)
merged_long[merged_long.Year==2021].plot(kind='scatter',x='Income',y='SFBB',color='red', label='2021', ax=fig)
fig.set_xlabel("Income")
fig.set_ylabel("SFBB")
fig.set_title("Income & SFBB over time")
fig=plt.gcf()
fig.set_size_inches(30,20)
plt.show()

# %%
#UFBB plot
fig = merged_long[merged_long.Year==2016].plot(kind='scatter',x='Income',y='UFBB',color='#E0FFFF', label='2016')
merged_long[merged_long.Year==2017].plot(kind='scatter',x='Income',y='UFBB',color='#B2DFEE', label='2017', ax=fig)
merged_long[merged_long.Year==2018].plot(kind='scatter',x='Income',y='UFBB',color='#FF83FA', label='2018', ax=fig)
merged_long[merged_long.Year==2019].plot(kind='scatter',x='Income',y='UFBB',color='#8470FF', label='2019', ax=fig)
merged_long[merged_long.Year==2020].plot(kind='scatter',x='Income',y='UFBB',color='#5D478B', label='2020', ax=fig)
merged_long[merged_long.Year==2021].plot(kind='scatter',x='Income',y='UFBB',color='#551A8B', label='2021', ax=fig)
fig.set_xlabel("Income")
fig.set_ylabel("UFBB")
fig.set_title("Income & SFBB over time")
fig=plt.gcf()
fig.set_size_inches(30,20)
plt.show()

# %%
# ?plt.hexbin
fig = sns.jointplot(x='Income', y= 'UFBB', kind = "hex", data = merged_long)
plt.show()

# %%
fig = sns.jointplot(x='Income', y= 'SFBB', kind = "hex", data = merged_long)
plt.show()

# %% [markdown]
# # Building a Linear Model on the Data
# We will use 80% of data to train the model, and keep 20% of the data for testing (not included in tests/exams so can probbaly remove this too?)

# %%
x = merged_long[['Income', 'Year']]
y = merged_long[['UFBB']]

# %%
# Split into train and test data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 5)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1449, 2)
# (363, 2)
# (1449, 1)
# (363, 1)

# %%
linearmodel = lr().fit(x_train, y_train) 
score = linearmodel.score(x_train, y_train)
coef = linearmodel.coef_
#predict = linearmodel.predict(np.array([[3,5]]))

print(score)
print(coef) # scientific notation
# Out:
# 0.25957472913513746
# [[1.01118947e-03 8.61406344e+00]]

# %%
# Model testing
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# model evaluation for testing set
y_pred = linearmodel.predict(x_test) # using the model we fitted earlier, we get predictions 

mae = mean_absolute_error(y_test, y_pred)
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
r2 = r2_score(y_test, y_pred)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE score is {}'.format(mae)) # can range from 0 to ∞
print('RMSE is {}'.format(rmse)) # can range from 0 to ∞
print('R2 score is {}'.format(r2)) # 0 to 1
# Out:
# The model performance for testing set
# --------------------------------------
# MAE score is 23.484421410331993
# RMSE is 27.537550951973593
# R2 score is 0.28167600821840255

# %%
# Interpretation = very bad model fit
"""

The model performance for testing set
--------------------------------------
MAE score is 23.484421410331993
RMSE is 27.53755095197365
R2 score is 0.28167600821839955

MAE average magnitude of errors in a set of predictions (no direction)
    Can't find rule of thumb, but its bad
RMSE average magnitude of error in model (square difference between predition and observation)
    Rule of thumb: between 0.2 & 0.5 is relatively accurate
R2 amount of variation explained by model
"""
# Equation for regression line 
print("Coefficients: \n", linearmodel.coef_)
print("Intercept: \n", linearmodel.intercept_)

print("Equation: y = {:.2f} + {:.2f}*x1 + {:.2f}*x2".format(linearmodel.intercept_, linearmodel.coef_[1],
                                                          linearmodel.coef_[2]))
# Possible solutions: remove outliers
# Out:
# Coefficients:
#  [[1.01118947e-03 8.61406344e+00]]
# Intercept:
#  [-17377.57532613]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-1c943109da70> in <module>
#      18 print("Intercept: \n", linearmodel.intercept_)
#      19
# ---> 20 print("Equation: y = {:.2f} + {:.2f}*x1 + {:.2f}*x2".format(linearmodel.intercept_, linearmodel.coef_[1],
#      21                                                           linearmodel.coef_[2]))
#      22 # Possible solutions: remove outliers
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %% [markdown]
# # Searching for Outliers

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
fig.suptitle('Boxplots Long Data')
ax1.boxplot('SFBB', data = merged_long)
ax2.boxplot('UFBB', data = merged_long)
ax3.boxplot('Income', data = merged_long)

# %% [markdown]
# # Miscellaneous code

# %%
#SFBB plot other way around
fig = merged_long[merged_long.Year==2016].plot(kind='scatter',x='SFBB',y='Income',color='orange', label='2016')
merged_long[merged_long.Year==2017].plot(kind='scatter',x='SFBB',y='Income',color='blue', label='2017', ax=fig)
merged_long[merged_long.Year==2018].plot(kind='scatter',x='SFBB',y='Income',color='pink', label='2018', ax=fig)
merged_long[merged_long.Year==2019].plot(kind='scatter',x='SFBB',y='Income',color='green', label='2019', ax=fig)
merged_long[merged_long.Year==2020].plot(kind='scatter',x='SFBB',y='Income',color='cyan', label='2020', ax=fig)
merged_long[merged_long.Year==2021].plot(kind='scatter',x='SFBB',y='Income',color='red', label='2021', ax=fig)
fig.set_xlabel("SFBB")
fig.set_ylabel("Income")
fig.set_title("Income & SFBB over time")
fig=plt.gcf()
fig.set_size_inches(30,20)
plt.show()

# %%
#UFBB plot other way around
fig = merged_long[merged_long.Year==2016].plot(kind='scatter',x='UFBB',y='Income',color='orange', label='2016')
merged_long[merged_long.Year==2017].plot(kind='scatter',x='UFBB',y='Income',color='blue', label='2017', ax=fig)
merged_long[merged_long.Year==2018].plot(kind='scatter',x='UFBB',y='Income',color='pink', label='2018', ax=fig)
merged_long[merged_long.Year==2019].plot(kind='scatter',x='UFBB',y='Income',color='green', label='2019', ax=fig)
merged_long[merged_long.Year==2020].plot(kind='scatter',x='UFBB',y='Income',color='cyan', label='2020', ax=fig)
merged_long[merged_long.Year==2021].plot(kind='scatter',x='UFBB',y='Income',color='red', label='2021', ax=fig)
fig.set_xlabel("UFBB")
fig.set_ylabel("Income")
fig.set_title("Income & UFBB over time")
fig=plt.gcf()
fig.set_size_inches(30,20)
plt.show()

# %%
# SFBB Linear regression model
x1 = merged_long[['Year', 'Income']]
y1 = merged_long[['SFBB']]
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
slinearmodel = lr().fit(x_train, y_train) 
sscore = slinearmodel.score(x_train, y_train)
scoef = slinearmodel.coef_

y_predi = slinearmodel.predict(x_test) # using the model we fitted earlier, we get predictions 

smae = mean_absolute_error(y_test, y_predi)
srmse = (np.sqrt(mean_squared_error(y_test, y_predi)))
sr2 = r2_score(y_test, y_predi)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE score is {}'.format(smae)) # can range from 0 to ∞
print('RMSE is {}'.format(srmse)) # can range from 0 to ∞
print('R2 score is {}'.format(sr2)) # 0 to 1

# %%
## Logistic regression: Not what we need (categorical outcome)
# Turning year into 0-5
#merged_long.loc[merged_long['Year'] == 2016, 'Year'] = 0
#merged_long.loc[merged_long['Year'] == 2017, 'Year'] = 1
#merged_long.loc[merged_long['Year'] == 2018, 'Year'] = 2
#merged_long.loc[merged_long['Year'] == 2019, 'Year'] = 3
#merged_long.loc[merged_long['Year'] == 2020, 'Year'] = 4
#merged_long.loc[merged_long['Year'] == 2021, 'Year'] = 5

#from sklearn.linear_model import LogisticRegression

# Let's compute the logistic regression
# Initiate your logistic model
#logit = LogisticRegression()
# Fit your logistic regression model to your train model
#logit.fit(x_train, y_train)

# %%
# Area Plot (probably the most useful for combined data)

x = ['Income']
y1 = ['2016 UFBB availability (% premises)']
y2 = ['2017 UFBB availability (% premises)']
y3 = ['2018 UFBB availability (% premises)']
y4 = ['2019 UFBB availability (% premises)']
y5 = ['2020 UFBB availability (% premises)']
y6 = ['2021 UFBB availability (% premises)']


# data:
plt.stackplot(x, y1, y2, y3, y4, y5, y6, labels=['2016','2017','2018','2019','2020', '2021'])

plt.xlabel('Income')
plt.ylabel('Internet availability')
plt.title('UFBB')

plt.legend()

# can probably also add legend code into the stackplot thing

# This graph shows how an area plot can be plotted for the present scenario. 
# Each shaded area in the graph shows a particular team with the frequency variations 
# denoting the distance covered by the team on different days.

# %%
# legend:
plt.plot([],[],color='k', label='2016', linewidth=5, alpha=0.5)
plt.plot([],[],color='c', label='2017', linewidth=5, alpha=0.5)
plt.plot([],[],color='y', label='2018', linewidth=5, alpha=0.5)
plt.plot([],[],color='m', label='2019', linewidth=5, alpha=0.5)
plt.plot([],[],color='r', label='2020', linewidth=5, alpha=0.5)
plt.plot([],[],color='g', label='2021', linewidth=5, alpha=0.5)

# %%
#UFBB plot
fig = merged_long[merged_long.Year==2016].plot(kind='scatter',x='Income',y='UFBB',color='orange', label='2016')
merged_long[merged_long.Year==2017].plot(kind='scatter',x='Income',y='UFBB',color='blue', label='2017', ax=fig)
merged_long[merged_long.Year==2018].plot(kind='scatter',x='Income',y='UFBB',color='pink', label='2018', ax=fig)
merged_long[merged_long.Year==2019].plot(kind='scatter',x='Income',y='UFBB',color='green', label='2019', ax=fig)
merged_long[merged_long.Year==2020].plot(kind='scatter',x='Income',y='UFBB',color='cyan', label='2020', ax=fig)
merged_long[merged_long.Year==2021].plot(kind='scatter',x='Income',y='UFBB',color='red', label='2021', ax=fig)
fig.set_xlabel("Income")
fig.set_ylabel("UFBB")
fig.set_title("Income & SFBB over time")
fig=plt.gcf()
fig.set_size_inches(30,20)
plt.show()
